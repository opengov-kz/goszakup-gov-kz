# %%
import requests
import pandas as pd
import time
import os
from datetime import datetime, timedelta

GRAPHQL_URL = "https://ows.goszakup.gov.kz/v3/graphql"

HEADERS = {
    "Content-Type": "application/json",
    "Authorization": "Bearer d5c3d78fc111d88a0a37b4ab8f83cbd5"
}

query_template = """
query GetPlans($filter: PlansFiltersInput, $after: Int) {
    Plans(filter: $filter, limit: 200, after: $after) {
        id
        dateCreate
        PlansKato {
            id
            plnPointsId
            refKatoCode
            refCountriesCode
            fullDeliveryPlaceNameRu
            fullDeliveryPlaceNameKz
            count
            systemId
        }
    }
}
"""

output_dir = "plans_data"
os.makedirs(output_dir, exist_ok=True)
combined_file = os.path.join(output_dir, "plans_combined.parquet")
temp_dir = os.path.join(output_dir, "temp")
os.makedirs(temp_dir, exist_ok=True)

# Определяем начальную дату и after
if os.path.exists(combined_file):
    existing_df = pd.read_parquet(combined_file)
    last_date_create = pd.to_datetime(existing_df["dateCreate"].max())
    next_date_create = (last_date_create + timedelta(seconds=1)).strftime("%Y-%m-%d %H:%M:%S")
    variables = {"filter": {"dateCreate": next_date_create}, "after": None}
    print(f"📂 Найден файл с последней датой: {last_date_create}")
else:
    variables = {"filter": {"dateCreate": "2025-03-20 00:00:00"}, "after": None}
    print("📂 Начинаем сбор с начальной даты: 2025-03-20 00:00:00")

batch_size_limit = 100000  # Лимит размера батча
request_count = 0
batch_count = 0
plans_batch = []

while True:
    request_count += 1
    print(f"🔄 Запрос #{request_count} (after={variables['after']})")

    try:
        response = requests.post(GRAPHQL_URL, json={"query": query_template, "variables": variables}, headers=HEADERS, timeout=10)
        response.raise_for_status()
        data = response.json()

        if "errors" in data:
            print(f"❌ Ошибка API: {data['errors']}")
            break

        plans = data.get("data", {}).get("Plans", [])
        if not plans:
            print("✅ Все данные загружены.")
            break

        for plan in plans:
            for kato in plan.get("PlansKato", []):
                plans_batch.append({
                    "plan_id": plan["id"],
                    "dateCreate": plan["dateCreate"],
                    "kato_id": kato["id"],
                    "plnPointsId": kato["plnPointsId"],
                    "refKatoCode": kato["refKatoCode"],
                    "refCountriesCode": kato["refCountriesCode"],
                    "fullDeliveryPlaceNameRu": kato["fullDeliveryPlaceNameRu"],
                    "fullDeliveryPlaceNameKz": kato["fullDeliveryPlaceNameKz"],
                    "count": kato["count"],
                    "systemId": kato["systemId"]
                })
        
        if len(plans_batch) >= batch_size_limit:
            batch_count += 1
            temp_file = os.path.join(temp_dir, f"plans_batch_{batch_count}.parquet")
            pd.DataFrame(plans_batch).to_parquet(temp_file, index=False)
            print(f"💾 Сохранён временный файл: {temp_file} ({len(plans_batch)} записей)")
            plans_batch = []

        variables["after"] = plans[-1]["id"]
        time.sleep(1)
    except Exception as e:
        print(f"⚠️ Ошибка: {e}")
        break

# Сохранение оставшихся данных
if plans_batch:
    batch_count += 1
    temp_file = os.path.join(temp_dir, f"plans_batch_{batch_count}.parquet")
    pd.DataFrame(plans_batch).to_parquet(temp_file, index=False)
    print(f"💾 Сохранён временный файл: {temp_file} ({len(plans_batch)} записей)")

# Объединение временных файлов
temp_files = [os.path.join(temp_dir, f) for f in os.listdir(temp_dir) if f.endswith(".parquet")]
if temp_files:
    print(f"🔄 Объединяем {len(temp_files)} временных файлов...")
    df_list = [pd.read_parquet(f) for f in temp_files]
    all_data = pd.concat(df_list, ignore_index=True)
    if os.path.exists(combined_file):
        existing_df = pd.read_parquet(combined_file)
        all_data = pd.concat([existing_df, all_data]).drop_duplicates(subset=["plan_id", "kato_id"], keep="last")
    all_data.to_parquet(combined_file, index=False)
    print(f"✅ Данные обновлены в {combined_file} ({len(all_data)} записей)")
    
    # Удаление временных файлов
    for temp_file in temp_files:
        os.remove(temp_file)
    print("🗑️ Временные файлы удалены.")

print(f"✅ Завершено. Всего записей в итоговом файле: {len(pd.read_parquet(combined_file))}")

# Проверка результата
df = pd.read_parquet(combined_file)
print("\nПервые 5 строк:")
display(df.head(5))
print("\nПоследние 5 строк:")
display(df.tail(5))
# Out:
# 📂 Найден файл с последней датой: 2025-03-25 14:56:19
# 🔄 Запрос #1 (after=None)
# ✅ Все данные загружены.
# ✅ Завершено. Всего записей в итоговом файле: 1490

# %%
# Проверка результата
df = pd.read_parquet(combined_file)
print("\nПервые 5 строк:")
display(df.head(5))
print("\nПоследние 5 строк:")
display(df.tail(5))
# Out:
# Первые 5 строк:
#     plan_id           dateCreate   kato_id  plnPointsId refKatoCode  \
# 0  78319870  2025-03-25 14:56:19  97625939     78319870   614430100
# 1  78319854  2025-03-25 14:53:13  97625917     78319854   614430100
# 2  78319835  2025-03-25 14:49:51  97625892     78319835   614430100
# 3  78319795  2025-03-25 14:43:00  97625838     78319795   614430100
# 4  78319768  2025-03-25 14:38:02  97625810     78319768   614430100
#
#   refCountriesCode                            fullDeliveryPlaceNameRu  \
# 0              398  Туркестанская область, Мактааральский район, п...
# 1              398  Туркестанская область, Мактааральский район, п...
# 2              398  Туркестанская область, Мактааральский район, п...
# 3              398  Туркестанская область, Мактааральский район, п...
# 4              398  Туркестанская область, Мактааральский район, п...
#
#                              fullDeliveryPlaceNameKz  count  systemId
# 0  Түркістан облысы, Мақтаарал ауданы, Мырзакент ...    4.0         3
# 1  Түркістан облысы, Мақтаарал ауданы, Мырзакент ...   10.0         3
# 2  Түркістан облысы, Мақтаарал ауданы, Мырзакент ...   20.0         3
# 3  Түркістан облысы, Мақтаарал ауданы, Мырзакент ...   10.0         3
# 4  Түркістан облысы, Мақтаарал ауданы, Мырзакент ...    8.0         3
# Последние 5 строк:
#        plan_id           dateCreate   kato_id  plnPointsId refKatoCode  \
# 1485  78296914  2025-03-20 00:03:17  97595602     78296914   751210000
# 1486  78296907  2025-03-20 00:02:13  97595594     78296907   751210000
# 1487  78296904  2025-03-20 00:01:27  97595591     78296904   751210000
# 1488  78296898  2025-03-20 00:00:39  97595585     78296898   751210000
# 1489  78296894  2025-03-20 00:00:03  97595580     78296894   751210000
#
#      refCountriesCode                            fullDeliveryPlaceNameRu  \
# 1485              398  г.Алматы, Алатауский район г.Алматы, Алатауски...
# 1486              398  г.Алматы, Алатауский район г.Алматы, Алатауски...
# 1487              398  г.Алматы, Алатауский район г.Алматы, Алатауски...
# 1488              398  г.Алматы, Алатауский район г.Алматы, Алатауски...
# 1489              398  г.Алматы, Алатауский район г.Алматы, Алатауски...
#
#                                 fullDeliveryPlaceNameKz  count  systemId
# 1485  Алматы қ., Алатау ауданы Алматы қ., Алатау ауд...    1.0         3
# 1486  Алматы қ., Алатау ауданы Алматы қ., Алатау ауд...    1.0         3
# 1487  Алматы қ., Алатау ауданы Алматы қ., Алатау ауд...    1.0         3
# 1488  Алматы қ., Алатау ауданы Алматы қ., Алатау ауд...    1.0         3
# 1489  Алматы қ., Алатау ауданы Алматы қ., Алатау ауд...    1.0         3
